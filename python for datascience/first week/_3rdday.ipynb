# %%
import os
print(os.getcwd())
# Out:
# c:\Users\tonys\OneDrive\Documents\academic\fifth sem\python for datascience\class

# %%
try:
    n1=int(input("enter a number"))
    n2=int(input("enter another number"))
    result=n1/n2
    print("result is",result)
except ValueError:
    print("please enter valid number")
except ZeroDivisionError:
    print("you can not divide by zero")
finally:
    print("this always runs")
# Out:
# result is 0.5
# this always runs

# %%
from collections import Counter
nums=[1,2,2,3,3,3]
c=Counter(nums)
print(c)
print(d)
# Out:
# Counter({3: 3, 2: 2, 1: 1})
# ['ram', 'shyam', [1, 2, 2, 3, 3, 3]]

# %%
from collections import defaultdict
aDict=defaultdict(int)
aDict["a"]=aDict["a"]+1
print(aDict)
# Out:
# defaultdict(<class 'int'>, {'a': 1})

# %%
from collections import deque

q=deque([1,2,3])

q.appendleft(1)
print(q)
q.pop()
print(q)
q.append(1)
print(q)
q.popleft()
print(q)
# Out:
# deque([1, 1, 2, 3])
# deque([1, 1, 2])
# deque([1, 1, 2, 1])
# deque([1, 2, 1])

# %%
from collections import namedtuple
Point= namedtuple('Point','x y')
p=Point(3,4)
print(p.x,p.y)
print(p)
# Out:
# 3 4
# Point(x=3, y=4)
