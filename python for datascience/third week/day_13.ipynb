# %%
import pandas as pd

# %%
import random
import tqdm
names=['ram','shyam','hari','krishna','sita']
final_list=[]
for i in tqdm.tqdm(range(1,10000)):
    random_name=names[random.randint(0,4)]
    final_list.append({
        "EID":i,
        "Name":random_name,
        "Salary":100000*random.random()
    })
    df=pd.DataFrame(final_list)
    df.to_csv("big_data.csv")
# Out:
#  58%|█████▊    | 5777/9999 [01:11<00:52, 81.06it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#       7 final_list.append({
#       8     "EID":i,
#       9     "Name":random_name,
#      10     "Salary":100000*random.random()
#      11 })
#      12 df=pd.DataFrame(final_list)
# ---> 13 df.to_csv("big_data.csv")
#
# File c:\Users\tonys\.conda\envs\AI\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
first_chunk=True
output_file='processed_data.csv'
for chunk in pd.read_csv('big_data.csv',chunksize=100):
    chunk['Gender']=chunk['Name'].apply(lambda x:'Female' if x in "sita" else 'M')
    chunk.to_csv(output_file,
                 index=False,
                 mode='w' if first_chunk else 'a',
                 header=first_chunk)
    first_chunk=False

# %%
import numpy as np
